# %% [markdown]
# # Utilização do PyQGIS no Jupyter

# %% [markdown]
# ### Webografia
# * https://lerryws.xyz/posts/PyQGIS-in-Jupyter-Notebook
# * https://github.com/3liz/qgis-nbextension/blob/master/examples/render_layer.py
# * https://docs.qgis.org/testing/en/docs/pyqgis_developer_cookbook/

# %% [markdown]
# ### Primeiro ensaio
# Os paths específicos da versão de desenvolvimento instalada no meu computador.

# %%
import os
import sys
from osgeo import ogr
#os.environ['QT_QPA_PLATFORM'] = 'offscreen'
#sys.path.insert(0,'/usr/local/share/qgis/python')
from qgis.core import *
#QgsApplication.setPrefixPath("/usr/local", True) 
#from qgis.server import *
from qgis.gui import *
from qgis import processing

from qgis.PyQt.QtGui import QColor, QImage
from qgis.PyQt.QtCore import QSize, QBuffer, QIODevice

qgs = QgsApplication([], False)
qgs.initQgis()
print(QgsApplication.showSettings())
# Out:
# Application state:
# QGIS_PREFIX_PATH env var:		C:/OSGEO4~1/apps/qgis
# Prefix:		C:/OSGEO4~1/apps/qgis
# Plugin Path:		C:/OSGEO4~1/apps/qgis/plugins
# Package Data Path:	C:/OSGEO4~1/apps/qgis/.
# Active Theme Name:
# Active Theme Path:	C:/OSGEO4~1/apps/qgis/./resources/themes\\icons/
# Default Theme Path:	:/images/themes/default/
# SVG Search Paths:	C:/OSGEO4~1/apps/qgis/./svg/
# 		C:/Users/Marcelo/AppData/Roaming/python3\profiles\default/svg/
# User DB Path:	C:/OSGEO4~1/apps/qgis/./resources/qgis.db
# Auth DB Path:	C:/Users/Marcelo/AppData/Roaming/python3\profiles\default/qgis-auth.db

# %%
covid_gpkg = "covid-pt-2020-04-16.gpkg" + "|layername=concelho"
vlayer = QgsVectorLayer(covid_gpkg, "Concelhos", "ogr")
if not vlayer.isValid():
    print("Layer failed to load!")
else:
    QgsProject.instance().addMapLayer(vlayer)
    print("Layer loaded")
# Out:
# Layer loaded

# %%
covid_gpkg = "covid-pt-2020-04-16.gpkg"
conn = ogr.Open(covid_gpkg)
for i in conn:
    vlayer = QgsVectorLayer("{}|layername={}".format(covid_gpkg, i.GetName()), i.GetName(), "ogr")
    if not vlayer.isValid():
        print("Layer {} failed to load".format(i.GetName()))
    else:
        QgsProject.instance().addMapLayer(vlayer)
        print("Layer {} loaded".format(i.GetName()))
# Out:
# Layer concelho loaded
# Layer raa_central_concelho loaded
# Layer raa_ocidental_concelho loaded
# Layer raa_oriental_concelho loaded
# Layer ram_concelho loaded
# Layer layer_styles loaded
# Layer confirmados_concelho loaded
# Layer situacao_epidemiologica loaded

# %%
concelho = QgsProject.instance().mapLayersByName('concelho')[0]

# %%
for c in concelho.getFeatures():
        print("Em {} há {} caso(s) confirmados".format(c["concelho"], c["confirmados_concelho_16/04/2020"]))
# Out:
# Em ÁGUEDA há 22 caso(s) confirmados
# Em ALBERGARIA-A-VELHA há 52 caso(s) confirmados
# Em ANADIA há 7 caso(s) confirmados
# Em AROUCA há 14 caso(s) confirmados
# Em AVEIRO há 130 caso(s) confirmados
# Em CASTELO DE PAIVA há 3 caso(s) confirmados
# Em ESPINHO há 28 caso(s) confirmados
# Em ESTARREJA há 33 caso(s) confirmados
# Em SANTA MARIA DA FEIRA há 187 caso(s) confirmados
# Em ALMEIRIM há 8 caso(s) confirmados
# Em ALPIARÇA há 3 caso(s) confirmados
# Em BENAVENTE há 13 caso(s) confirmados
# Em CARTAXO há 9 caso(s) confirmados
# Em CHAMUSCA há NULL caso(s) confirmados
# Em CONSTÂNCIA há NULL caso(s) confirmados
# Em CORUCHE há 7 caso(s) confirmados
# Em ENTRONCAMENTO há NULL caso(s) confirmados
# Em FERREIRA DO ZÊZERE há NULL caso(s) confirmados
# Em GOLEGÃ há NULL caso(s) confirmados
# Em MAÇÃO há NULL caso(s) confirmados
# Em RIO MAIOR há 4 caso(s) confirmados
# Em SALVATERRA DE MAGOS há 3 caso(s) confirmados
# Em SANTARÉM há 29 caso(s) confirmados
# Em SARDOAL há NULL caso(s) confirmados
# Em TOMAR há 4 caso(s) confirmados
# Em TORRES NOVAS há 3 caso(s) confirmados
# Em VILA NOVA DA BARQUINHA há NULL caso(s) confirmados
# Em OURÉM há 10 caso(s) confirmados
# Em ALCÁCER DO SAL há NULL caso(s) confirmados
# Em ALCOCHETE há 5 caso(s) confirmados
# Em ALMADA há 91 caso(s) confirmados
# Em BARREIRO há 53 caso(s) confirmados
# Em GRÂNDOLA há 3 caso(s) confirmados
# Em MOITA há 29 caso(s) confirmados
# Em MONTIJO há 22 caso(s) confirmados
# Em PALMELA há 11 caso(s) confirmados
# Em SANTIAGO DO CACÉM há 6 caso(s) confirmados
# Em SEIXAL há 92 caso(s) confirmados
# Em SESIMBRA há 10 caso(s) confirmados
# Em SETÚBAL há 34 caso(s) confirmados
# Em SINES há 3 caso(s) confirmados
# Em ARCOS DE VALDEVEZ há 12 caso(s) confirmados
# Em CAMINHA há 4 caso(s) confirmados
# Em MELGAÇO há 7 caso(s) confirmados
# Em MONÇÃO há 5 caso(s) confirmados
# Em PAREDES DE COURA há 3 caso(s) confirmados
# Em PONTE DA BARCA há NULL caso(s) confirmados
# Em PONTE DE LIMA há NULL caso(s) confirmados
# Em VALENÇA há 3 caso(s) confirmados
# Em VIANA DO CASTELO há 38 caso(s) confirmados
# Em VILA NOVA DE CERVEIRA há NULL caso(s) confirmados
# Em ALIJÓ há NULL caso(s) confirmados
# Em BOTICAS há NULL caso(s) confirmados
# Em CHAVES há 11 caso(s) confirmados
# Em MESÃO FRIO há NULL caso(s) confirmados
# Em MONDIM DE BASTO há NULL caso(s) confirmados
# Em MONTALEGRE há NULL caso(s) confirmados
# Em MURÇA há NULL caso(s) confirmados
# Em PESO DA RÉGUA há 9 caso(s) confirmados
# Em RIBEIRA DE PENA há NULL caso(s) confirmados
# Em SABROSA há NULL caso(s) confirmados
# Em SANTA MARTA DE PENAGUIÃO há NULL caso(s) confirmados
# Em VALPAÇOS há 3 caso(s) confirmados
# Em VILA POUCA DE AGUIAR há 3 caso(s) confirmados
# Em VILA REAL há 124 caso(s) confirmados
# Em ARMAMAR há NULL caso(s) confirmados
# Em CARREGAL DO SAL há 3 caso(s) confirmados
# Em CASTRO DAIRE há 5 caso(s) confirmados
# Em CINFÃES há 4 caso(s) confirmados
# Em LAMEGO há 8 caso(s) confirmados
# Em MANGUALDE há NULL caso(s) confirmados
# Em MOIMENTA DA BEIRA há NULL caso(s) confirmados
# Em MORTÁGUA há 3 caso(s) confirmados
# Em NELAS há 8 caso(s) confirmados
# Em OLIVEIRA DE FRADES há 7 caso(s) confirmados
# Em PENALVA DO CASTELO há NULL caso(s) confirmados
# Em PENEDONO há NULL caso(s) confirmados
# Em RESENDE há 37 caso(s) confirmados
# Em SANTA COMBA DÃO há NULL caso(s) confirmados
# Em SÃO JOÃO DA PESQUEIRA há NULL caso(s) confirmados
# Em SÃO PEDRO DO SUL há 4 caso(s) confirmados
# Em SÁTÃO há NULL caso(s) confirmados
# Em SERNANCELHE há NULL caso(s) confirmados
# Em TABUAÇO há NULL caso(s) confirmados
# Em TAROUCA há NULL caso(s) confirmados
# Em TONDELA há NULL caso(s) confirmados
# Em VILA NOVA DE PAIVA há NULL caso(s) confirmados
# Em VISEU há 24 caso(s) confirmados
# Em VOUZELA há NULL caso(s) confirmados

# %%
expr_sem_casos = QgsExpression( " \"confirmados_concelho_16/04/2020\" IS NULL " )
virgens = list(concelho.getFeatures( QgsFeatureRequest( expr_sem_casos ) ))
for c in virgens:
        print("Em {} não há pelos menos 3 casos confirmados".format(c["concelho"]))
# Out:
# Em SEVER DO VOUGA não há pelos menos 3 casos confirmados
# Em ALJUSTREL não há pelos menos 3 casos confirmados
# Em ALMODÔVAR não há pelos menos 3 casos confirmados
# Em ALVITO não há pelos menos 3 casos confirmados
# Em BARRANCOS não há pelos menos 3 casos confirmados
# Em CASTRO VERDE não há pelos menos 3 casos confirmados
# Em CUBA não há pelos menos 3 casos confirmados
# Em FERREIRA DO ALENTEJO não há pelos menos 3 casos confirmados
# Em MÉRTOLA não há pelos menos 3 casos confirmados
# Em MOURA não há pelos menos 3 casos confirmados
# Em ODEMIRA não há pelos menos 3 casos confirmados
# Em OURIQUE não há pelos menos 3 casos confirmados
# Em VIDIGUEIRA não há pelos menos 3 casos confirmados
# Em CABECEIRAS DE BASTO não há pelos menos 3 casos confirmados
# Em TERRAS DE BOURO não há pelos menos 3 casos confirmados
# Em ALFÂNDEGA DA FÉ não há pelos menos 3 casos confirmados
# Em FREIXO DE ESPADA À CINTA não há pelos menos 3 casos confirmados
# Em MIRANDA DO DOURO não há pelos menos 3 casos confirmados
# Em MOGADOURO não há pelos menos 3 casos confirmados
# Em TORRE DE MONCORVO não há pelos menos 3 casos confirmados
# Em VILA FLOR não há pelos menos 3 casos confirmados
# Em BELMONTE não há pelos menos 3 casos confirmados
# Em CASTELO BRANCO não há pelos menos 3 casos confirmados
# Em COVILHÃ não há pelos menos 3 casos confirmados
# Em FUNDÃO não há pelos menos 3 casos confirmados
# Em IDANHA-A-NOVA não há pelos menos 3 casos confirmados
# Em OLEIROS não há pelos menos 3 casos confirmados
# Em PENAMACOR não há pelos menos 3 casos confirmados
# Em PROENÇA-A-NOVA não há pelos menos 3 casos confirmados
# Em SERTÃ não há pelos menos 3 casos confirmados
# Em VILA DE REI não há pelos menos 3 casos confirmados
# Em VILA VELHA DE RÓDÃO não há pelos menos 3 casos confirmados
# Em ARGANIL não há pelos menos 3 casos confirmados
# Em MIRA não há pelos menos 3 casos confirmados
# Em OLIVEIRA DO HOSPITAL não há pelos menos 3 casos confirmados
# Em MARVÃO não há pelos menos 3 casos confirmados
# Em MONFORTE não há pelos menos 3 casos confirmados
# Em NISA não há pelos menos 3 casos confirmados
# Em PONTE DE SOR não há pelos menos 3 casos confirmados
# Em PORTALEGRE não há pelos menos 3 casos confirmados
# Em SOUSEL não há pelos menos 3 casos confirmados
# Em ABRANTES não há pelos menos 3 casos confirmados
# Em ALCANENA não há pelos menos 3 casos confirmados
# Em CHAMUSCA não há pelos menos 3 casos confirmados
# Em CONSTÂNCIA não há pelos menos 3 casos confirmados
# Em ENTRONCAMENTO não há pelos menos 3 casos confirmados
# Em FERREIRA DO ZÊZERE não há pelos menos 3 casos confirmados
# Em GOLEGÃ não há pelos menos 3 casos confirmados
# Em MAÇÃO não há pelos menos 3 casos confirmados
# Em SARDOAL não há pelos menos 3 casos confirmados
# Em VILA NOVA DA BARQUINHA não há pelos menos 3 casos confirmados
# Em ALCÁCER DO SAL não há pelos menos 3 casos confirmados
# Em PONTE DA BARCA não há pelos menos 3 casos confirmados
# Em PONTE DE LIMA não há pelos menos 3 casos confirmados
# Em VILA NOVA DE CERVEIRA não há pelos menos 3 casos confirmados
# Em ALIJÓ não há pelos menos 3 casos confirmados
# Em BOTICAS não há pelos menos 3 casos confirmados
# Em MESÃO FRIO não há pelos menos 3 casos confirmados
# Em MONDIM DE BASTO não há pelos menos 3 casos confirmados
# Em MONTALEGRE não há pelos menos 3 casos confirmados
# Em MURÇA não há pelos menos 3 casos confirmados
# Em RIBEIRA DE PENA não há pelos menos 3 casos confirmados
# Em SABROSA não há pelos menos 3 casos confirmados
# Em SANTA MARTA DE PENAGUIÃO não há pelos menos 3 casos confirmados
# Em ARMAMAR não há pelos menos 3 casos confirmados
# Em MANGUALDE não há pelos menos 3 casos confirmados
# Em MOIMENTA DA BEIRA não há pelos menos 3 casos confirmados
# Em PENALVA DO CASTELO não há pelos menos 3 casos confirmados
# Em PENEDONO não há pelos menos 3 casos confirmados
# Em SANTA COMBA DÃO não há pelos menos 3 casos confirmados
# Em SÃO JOÃO DA PESQUEIRA não há pelos menos 3 casos confirmados
# Em SÁTÃO não há pelos menos 3 casos confirmados
# Em SERNANCELHE não há pelos menos 3 casos confirmados
# Em TABUAÇO não há pelos menos 3 casos confirmados
# Em TAROUCA não há pelos menos 3 casos confirmados
# Em TONDELA não há pelos menos 3 casos confirmados
# Em VILA NOVA DE PAIVA não há pelos menos 3 casos confirmados
# Em VOUZELA não há pelos menos 3 casos confirmados

# %%
from qgis.PyQt.QtGui import QColor, QImage
from qgis.PyQt.QtCore import QSize, QBuffer, QIODevice

# %%
xt = concelho.extent()
# print(xt)
width  = 200
height = int(width*xt.height()/xt.width())
print("Gerar mapa com {} por {}".format(width, height))

options = QgsMapSettings()
options.setLayers([concelho])
options.setBackgroundColor(QColor(255, 255, 255))
options.setOutputSize(QSize(width, height))
options.setExtent(xt)
           
render = QgsMapRendererParallelJob(options)
render.start()
render.waitForFinished()

image = render.renderedImage()
# Out:
# Gerar mapa com 200 por 409

# %%
from IPython.display import Image

# %%
imgbuf= QBuffer()
imgbuf.open( QIODevice.ReadWrite )
image.save( imgbuf,"PNG" )
Image( imgbuf.data() )

# %%
qgs.exitQgis()
